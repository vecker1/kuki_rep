# %%
import pandas as pd

import seaborn as sns
sns.set(color_codes=True)

import matplotlib.pyplot as plt

data = pd.read_csv("zootest.csv")

data
# Out:
#     animal_name  hair_boolean  feathers_boolean  eggs_boolean  milk_boolean  \
# 0      aardvark             1                 0             0             1
# 1      antelope             1                 0             0             1
# 2          bass             0                 0             1             0
# 3          bear             1                 0             0             1
# 4          boar             1                 0             0             1
# ..          ...           ...               ...           ...           ...
# 96      wallaby             1                 0             0             1
# 97         wasp             1                 0             1             0
# 98         wolf             1                 0             0             1
# 99         worm             0                 0             1             0
# 100        wren             0                 1             1             0
#
# ...

# %%
conteo = data['hair_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales que tienen pelo')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0)  # Etiquetas del eje x

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['feathers_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales que tienen plumas')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0)  # Etiquetas del eje x

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['eggs_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales que producen huevos')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0)  # Etiquetas del eje x

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['milk_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales dan leche')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['airborne_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales que vuelan')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['aquatic_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales que nadan')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['predator_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales depredadores')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['toothed_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales que tienen dientes')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['backbone_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales con columna vertebral')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['breathes_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales que respiran oxigeno')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([1, 0], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['venomous_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales venenosos')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['fins_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales con aletas')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
sns.displot(data['legs_numeric'], kde=True, color="green")

# %%
conteo = data['tail_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales con cola')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([1, 0], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
conteo = data['domestic_boolean'].value_counts()

ax=conteo.plot(kind='bar', color=['blue', 'green'])

plt.title('Cantidad de animales domesticos')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['no', 'si'], rotation=0) 

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')

plt.show()

# %%
# Agrupa los datos por la columna 'mi_columna_booleana' y cuenta los valores de 0 y 1
conteo = data['type_numeric'].value_counts()

# Crea un gráfico de barras para mostrar la comparación
ax=conteo.plot(kind='bar', color=['blue', 'green'])

# Personaliza el gráfico
plt.title('Clase de Animales')
plt.xlabel('Booleano')
plt.ylabel('Cantidad')
plt.xticks([0, 1, 2, 3, 4, 5 , 6], ['Clase 1', 'Clase 2', 'Clase 4', 'Clase 7', 'Clase 6', 'Clase 3', 'Clase 5'], rotation=0)  # Etiquetas del eje x

for i, v in enumerate(conteo):
    ax.text(i, v + 0.1, str(v), color='black', fontweight='bold', ha='center')


# Muestra el gráfico
plt.show()
